# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# ### 1. Preguntas aclaratorias
#
# 1.  **Definición del Target y Fecha de Corte:** Dado que la información es válida al 1 de febrero de 2020, para los clientes que aún no se han ido (`EndDate` = 'No'), ¿debemos calcular su antigüedad (*tenure*) asumiendo esa fecha como el "hoy"?
# 2.  **Valores Ausentes en Servicios:** Al unir las tablas, los clientes que no aparecen en `internet.csv` o `phone.csv`, ¿deben ser tratados automáticamente como "No utiliza el servicio"? (por ejemplo, llenar con 'No' en las columnas de servicios técnicos).
# 3.  **Variable `TotalCharges`:** He notado que esta columna suele venir como texto y puede tener valores vacíos o espacios en blanco para clientes muy nuevos. ¿Cómo prefiere el equipo que tratemos estos casos? ¿Los eliminamos o los imputamos con el `MonthlyCharges`?
# 4.  **Uso de la variable `BeginDate`:** ¿Es recomendable utilizar la fecha exacta de inicio como característica, o es preferible transformar esta información en "Antigüedad en días/meses" para evitar que el modelo se sobreajuste a fechas específicas?
# 5.  **Balance de Clases:** ¿Existe alguna preferencia sobre cómo manejar el desbalance de los clientes que se van frente a los que se quedan (ej. técnicas de SMOTE o simplemente ajustar pesos en el modelo)?

# %% [markdown]
# ### 2. Plan de Trabajo Propuesto
#
# Este plan resume los pasos clave para llegar a la meta de un **AUC-ROC >= 0.88**.
#
# #### Paso 1: Preprocesamiento y Análisis Exploratorio (EDA)
# Cargaré los cuatro archivos, los uniré mediante `customerID` y realizaré una limpieza profunda: convertiré tipos de datos (especialmente fechas y cargos numéricos), gestionaré los valores nulos resultantes de la unión de tablas y crearé la columna objetivo (target) binaria. Analizaré visualmente cómo se distribuyen los cargos mensuales y la antigüedad para identificar patrones claros de abandono.
#
# #### Paso 2: Ingeniería de Características (Feature Engineering)
# Crearé nuevas variables que aporten valor, como el tiempo total de permanencia del cliente y el número total de servicios adicionales contratados. También aplicaré técnicas de codificación (como *One-Hot Encoding* para modelos lineales o *Label Encoding* para árboles) y escalamiento de variables numéricas para asegurar que todas las características contribuyan equitativamente al modelo.
#
# #### Paso 3: Entrenamiento y Selección de Modelos
# Entrenaré y compararé al menos tres algoritmos: Regresión Logística (como base), Random Forest y modelos de Gradient Boosting (como CatBoost, LightGBM o XGBoost). Utilizaré validación cruzada (*cross-validation*) para evaluar la estabilidad de los modelos y asegurar que el AUC-ROC sea representativo.
#
# #### Paso 4: Optimización de Hiperparámetros
# Seleccionaré el modelo con mejor desempeño inicial y realizaré un ajuste fino de sus parámetros (usando *RandomizedSearch*). El foco principal será maximizar la métrica AUC-ROC, cuidando de no caer en sobreajuste, y validando finalmente con el conjunto de prueba (test set).
#
# #### Paso 5: Conclusiones e Informe Final
# Prepararé una síntesis de los resultados, destacando cuáles son los factores que más influyen en que un cliente abandone Interconnect (importancia de características). Redactaré el informe final con recomendaciones de negocio claras para el equipo de marketing, basándome en los hallazgos del modelo.

# %% [markdown]
# # Comentario General del Revisor
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
# Tu plan de trabajo presenta una base organizada y coherente para abordar el proyecto. Se nota una intención clara de estructurar el proceso antes de ejecutar el análisis, lo cual es una práctica clave en entornos profesionales.
#
# #### Puntos Positivos:
#
# * **Estructuración del plan:** La secuencia de pasos permite visualizar con claridad cómo se desarrollará el proyecto.
# * **Enfoque analítico:** El planteamiento refleja comprensión de que un buen análisis comienza con exploración y definición estratégica.
# * **Claridad en la redacción:** Las ideas están expresadas de manera directa y comprensible.
# * **Visión metodológica:** Se evidencia una aproximación ordenada al problema.
#
# #### Oportunidades de Mejora:
#
# * Podrías fortalecer el plan especificando con mayor precisión qué resultado concreto se espera en cada paso. Esto ayudaría a que el avance sea más medible.
# * Sería valioso mencionar brevemente qué herramientas o técnicas planeas utilizar en cada etapa, para reforzar la viabilidad técnica del enfoque.
# * También podrías vincular explícitamente cada paso con el objetivo general del proyecto, asegurando una alineación aún más sólida.
#
# El trabajo muestra una base firme y con pequeños ajustes puede alcanzar un nivel aún más profesional y detallado.
#
# </div>
