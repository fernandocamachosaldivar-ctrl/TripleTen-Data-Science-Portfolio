# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>COMENTARIO GENERAL #1</b> <a class="tocSkip"></a>
#
# Felicidades Luis! Tu trabajo es excelente.
#
# Has completado todos los items necesarios para aprobar la entrega.
#
# Sigue así!
#
# </div>

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.
#
# voy a asiganar cada data frame a un variable para poder llamar la correcta cuando sea necesario, y foy a utilizar info() y hedad () para conocer los tipos de datos.
#
# de igual forma para saber si pandas ha reconocido cada dato como debe ser y saber si hay valores ausentes

# %%
import pandas as pd

# %%
orders_df= pd.read_csv('/Users/lcamacho/Triple Ten/Sprint 4/instacart_orders.csv',sep=';')
products_df= pd.read_csv('/Users/lcamacho/Triple Ten/Sprint 4/products.csv',sep=';')
aisles_df = pd.read_csv('/Users/lcamacho/Triple Ten/Sprint 4/aisles.csv',sep=';')
departments_df = pd.read_csv('/Users/lcamacho/Triple Ten/Sprint 4/departments.csv',sep=';')
order_products_df= pd.read_csv('/Users/lcamacho/Triple Ten/Sprint 4/order_products.csv', sep=';')

# %%
orders_df.info()
orders_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# ...

# %%
products_df.info()
products_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# ...

# %%
aisles_df.info()
aisles_df.head (5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
departments_df.info()
departments_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 468.0+ bytes
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
order_products_df.info()
order_products_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
#
# Todos los data frames estan ordenados de forma incorrecta, todos los indices estan en una sola columna por lo tanto, todos los datos de los indices de igual forma estan en una sola celda, hay que acomodarlos para poder hacer un correcto analisis. me di cuenta que los datos no estaban separados por ',' asi que indique que se separan por ';' para que los datos se expresen de dorma correcta.
#
# En cuando a los datos parecen estar completos, con execpto de la tabla products_df la columna product_name muestra valores nulos, lo que es va a necesitar un analisis para poder hacer un analisis correcto; de igua forma en orders_df hay valores ausentes en day_prior_order, pero esto puede ser logico siempre y cuando sea la primera compra de los clientes.
#
# En el data frame order_products_df muestra que la columna add_to_chart_order es tipo float64, al ser una orden secuencial creo que los mas apropiado seria convertirlo a int64

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
#
# Primero voy a revisar y eliminar datos duplicados, de igual forma basarme en especifico si hay numeros de indentificacion de cada data frame.
#
# tratar los valores ausentes que aparecen en orders_df, para poder sustituir los valores a 0.
#
# por ultimo correguir los tipos de datos, hacer que tengan un tipo de formato para su facil analisis.

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
print('cantidad de duplicados para orders_df:', orders_df.duplicated().sum())
# Out:
# cantidad de duplicados para orders_df: 15

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
#
# Si hay datos duplicados, Los datos duplicados son filas en las que los datos son completamente identicos, lo que es muy probable que se deba a un error, de igual forma demuestra que no son pedidos diferentes.

# %%
wednesday = orders_df['order_dow'] == 3
hour_2am = orders_df['order_hour_of_day'] == 2
wednesday_2am = orders_df[wednesday & hour_2am]
print('Total de pedidos el miercoles a las 2 am', len(wednesday_2am))
# Out:
# Total de pedidos el miercoles a las 2 am 121

# %% [markdown]
# ¿Qué sugiere este resultado?
#
# Lo que se puede observar es que 121 pedidos realizados ese dia en la madrugada es muy pequeño en comparacion al resto de las entradas del Data Frame, pero indica que hay un cierto gurpo de la poblacion que realiza pedidos a estas horas, por lo que valdria la pena seguir con disponibilidad en la platadorma

# %%
orders_df = orders_df.drop_duplicates().reset_index(drop=True)

# %%
print('cantidad de duplicados para orders_df:', orders_df.duplicated().sum())
# Out:
# cantidad de duplicados para orders_df: 0

# %%
print(orders_df['order_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos
#
# Se ha comprobado que no hay datos duplicados en especifico con la columna orders_id, de igual forma se comprobo que ya no hay datos duplicados, lo que va a facilitar el analisis de los datos ya que confirma que los datos ya estan limpios.

# %% [markdown]
# ### `products` data frame

# %%
print(products_df.duplicated().sum())
# Out:
# 0

# %%
print(products_df['product_id'].duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
print(products_df['product_name'].str.upper().duplicated().sum())
# Out:
# 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes
print(products_df['product_name'].dropna().str.upper().duplicated().sum())
# Out:
# 104

# %%
products_df['product_name']= products_df['product_name'].str.upper()

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Se pudo en contrar que no habia datos de ID duplicados, de igual forma ya se sabia que habia datos nulos en la columna product_name.
#
# el Hallazgo mas preocupante es que se encontraron nombres de productos iguales pero escritos de forma diferente, asignados a un numero de identificacion diferente, lo que se hizo fue estadarizar el formato para que se asigne a un solo numero de identificacion y que este corresponda al nombre del producto

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(departments_df.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
print(departments_df['department_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No exiten filas con copias exactas ni tampoco valores de identificacion en la columna de department_id
#
# no se requiere ninguna accion para hacer la limpieza

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(aisles_df.duplicated().sum())
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
print(aisles_df['aisle_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# No exiten filas con copias exactas ni tampoco valores de identificacion en la columna de aisle_id
#
# no se requiere ninguna accion para hacer la limpieza

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
print(order_products_df.duplicated().sum())
# Out:
# 0

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
print(order_products_df.duplicated(subset=['order_id', 'product_id']).sum())
# Out:
# 0

# %%
order_products_df = order_products_df.drop_duplicates(subset=['order_id', 'product_id'], keep='first').reset_index(drop=True)
print(order_products_df.duplicated(subset=['order_id', 'product_id']).sum())
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Se encontro que no habia filas que fueran copias completas
#
# pero se encontro que habia 1301 duplicados egañosos comprarando el numero de orden con el numero de producto se encontro que habia datos duplicados, lo que no es logico, ya que cada numero de orden y de producto deberian de ser diferentes. se deberian de eliminar estos valores ya que podrian afectar el analisis

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
print(products_df['product_name'].isnull().sum())
# Out:
# 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# al implementar el codigo drop_duplicates, se eliminaron todas las filas completamente ducplicadas, muestra que hay una cantidad de 1258 datos con nombres de productos faltantes

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
print(products_df[products_df['product_name'].isnull()])
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Si, los nombres de prodcuto faltante se encuentra en el pasillo 100, esto indica que todos los productos que no tienen nombre los registraron en el pasillo 100

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
nombres_producto_ausentes = products_df[products_df['product_name'].isnull()]
print(nombres_producto_ausentes['department_id'].unique())
# Out:
# [21]

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Si, como se habia mostrado en la tabla anterior, se puede observar que todos las filas con nombre de producto faltantes se encuentran en el pasillo 100 y en el departamento 21,

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
print(aisles_df[aisles_df['aisle_id'] == 100])
print(departments_df[departments_df['department_id'] == 21])
# Out:
#     aisle_id    aisle
# 99       100  missing
#     department_id department
# 20             21    missing

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# se confirma que cuendo el nombre el producto no esta definido se asigna al pasillo 100 y al departamento 21, esto nos ayuda a tenerlo en cuenta para considerar estos datos nulos y la forma en como estan organizados

# %%
# Completa los nombres de productos ausentes con 'Unknown'
products_df['product_name'].fillna('Unknown', inplace=True)
print(products_df['product_name'].isnull().sum())
# Out:
# 0
# C:\Users\lcamacho\AppData\Local\Temp\ipykernel_33176\1234145184.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df['product_name'].fillna('Unknown', inplace=True)

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# se identificaron que habia 1258 valores nulos, se descubrio que los valores ausentes no eran aleatorios, si no que se asiganoros a un pasillo y departamento especifico, para poder hacer un mejor analisis, su sustituyeron los valores nulos con 'Unknow' asi se va a poder hacer un analisis completo

# %% [markdown]
# ### `orders` data frame

# %%
# Encuentra los valores ausentes
print(orders_df.isnull().sum())
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
ordenes_ausentes = orders_df[orders_df['days_since_prior_order'].isnull()]
ausentes_pedidos_posteriores = (ordenes_ausentes['order_number'] > 1).any()
print(ausentes_pedidos_posteriores)
orders_df['days_since_prior_order'].fillna( 0, inplace=True)
# Out:
# False
# C:\Users\lcamacho\AppData\Local\Temp\ipykernel_33176\580142868.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   orders_df['days_since_prior_order'].fillna( 0, inplace=True)

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Primeramente se verificó que no hubiera datos duplicados, se encontró que únicamente En la columna de días desde la primera compra Había un gran número de datos nulos esto hasta cierto punto tendría sentido Siempre y cuando el cliente haya realizado su primer pedido se verificó la hipótesis utilizando un código En el que se filtraba los días posteriores de la primera orden y que el número de orden sea mayor a uno el resultado comprobó que únicamente los valores nulos son porque son primer pedido de cliente se sustituyeron los valores nulos por ser ya que los datos siguen siendo importantes para los análisis de los datos

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausentes
print(order_products_df.isnull().sum())
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
print(order_products_df['add_to_cart_order'].min())
print(order_products_df['add_to_cart_order'].max())
# Out:
# 1.0
# 64.0

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# se puede identificar que la unica columna con valores ausentes es add_to_cart_order lo que indica que no se registro correctamente la secuencia.
#
# tambien se puede ver que el numero minimo es 1 lo cual es logico, lo que indica que el primer producto que alguien agrega al carrito comienza con 1 y tambien muestra que el numero mayor es 64 lo que indica que es el pedido mas grande

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
pedidos_ausentes= order_products_df[order_products_df['add_to_cart_order'].isnull()]
pedidos_id_ausentes= pedidos_ausentes['order_id'].unique()
print(len(pedidos_id_ausentes))
# Out:
# 70

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
pedidos_involucrados = order_products_df[order_products_df['order_id'].isin(pedidos_id_ausentes)]
conteo_pedido = pedidos_involucrados.groupby('order_id').size()
cantidad_minima= conteo_pedido.min()
print(cantidad_minima)
# Out:
# 65

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos.
#
# Se identificaron valores ausentes, en la columna add_to_cart_order y tambien se encontro que no estaban al azar, si no que eran de 70 pedidos unicos, al hacer un analisis mas profundo se pudo encontrar que solo los pedidos grandes con mas de 64 articulos mostraban el error, posiblemente sea por un limite tecnico o de programacion

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.
order_products_df['add_to_cart_order'].fillna(999, inplace=True)
order_products_df['add_to_cart_order'] = order_products_df['add_to_cart_order'].astype(int)
# Out:
# C:\Users\lcamacho\AppData\Local\Temp\ipykernel_33176\3836866731.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   order_products_df['add_to_cart_order'].fillna(999, inplace=True)

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.
#
# Se modificaron los valores ausentes a 999 esto parapoder evitar una confusion y poder hacer un ejor analisis con los datos que son reales, de igual forma se cambiaron los datos de la columan a entero para poder hacer un mejor analisi

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
#
# Se hizo una preparacion de los datos para que se puedan hacer analisis correctos basados en datos claros y ordenados. se realizaron hipotesis y se intentaron comprobar mediante codigos
#
# primero hubo se analizaron los datos duplicados tanto impicitos como explicitos, y se corriguieron los datos
#
# se analizaron los valores asuentes, se investigo cada problema unico para entender la causa de los datos, donde se encontro que cada valor ausente tenia una razon y fueron tratadas de tal forma que no afecte nuestro analisis.

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:
#
# [A] (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas 'order_hour_of_day' y 'order_dow' de la tabla orders sean razonables (o sea, 'order_hour_of_day' va de 0 a 23 y 'order_dow' va de 0 a 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su próximo pedido, y comenta los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
hora_minima= orders_df['order_hour_of_day'].min()
hora_maxima= orders_df['order_hour_of_day'].max()

print(hora_minima)
print (hora_maxima)
# Out:
# 0
# 23

# %%
dia_minimo= orders_df['order_dow'].min()
dia_maximo= orders_df['order_dow'].max()

print(dia_minimo)
print(dia_maximo)
# Out:
# 0
# 6

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se hizo la berificacion y se demostro que todos los valores son razonables

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
from matplotlib import pyplot as plt

ordenes_hora = orders_df['order_hour_of_day'].value_counts().sort_index()
ordenes_hora.plot( x= ordenes_hora.index, y=ordenes_hora.values, title='Distribucion por hora', xlabel='Hora del dia', ylabel='Numero de pedidos', legend=False)
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# La actividad minima es en la noche y madrigada, los pedidos comienzan a aumentar a partir de las 5 5 am, teniendo mayor actividad a las 10 am hasta aproximadamente las 4 de la tarde, donde la activad comienza a discminuir drasticamente

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
ordenes_dia = orders_df['order_dow'].value_counts().sort_index()
ordenes_dia.plot( x= ordenes_dia.index, y=ordenes_dia.values, title='Distribucion por dia', xlabel='Dia de la semana', ylabel='Numero de pedidos', legend=False)
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se puede observar que los dias de mayor pedido es el domingo (0) probablemente las personas utilizan este dia para abastecerse para la semana, se muesta que conforme trancurren los dias el numero de pedidos decrese de forma significativa siendo el jueves (4) el dia en que hay menos pedidos

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
dias_espera= orders_df[orders_df['days_since_prior_order'] > 0]['days_since_prior_order']
dias_espera.hist(bins=30)
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se puede observar que hay una cantidad considerable de clientes que compran cada 7 dias, lo que refuerza la hipotesis que mucha gente hace sus compras cada semana, sin embargo, hay una gran cantidad de clientes que compran cada mes, de igual forma hay una gran caintdad de gente que hace pedidos alrededor de cada 5 dias, de igual forma se puede observar peñenos picos entre 14 y 21 dias, lo que de igualmente refuerza la teoria de que hay mas movimiento cada semana.

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
ordenes_miercoles = orders_df[orders_df['order_dow'] == 3]
ordenes_sabado = orders_df[orders_df['order_dow'] == 6]

# %%
conteo_horas_miercoles = ordenes_miercoles['order_hour_of_day'].value_counts().sort_index()
conteo_horas_sabado = ordenes_sabado['order_hour_of_day'].value_counts().sort_index()

# %%
comparacion_df = pd.DataFrame({'Miércoles': conteo_horas_miercoles,'Sábado': conteo_horas_sabado})

# %%
comparacion_df.plot(kind='bar', title='Comparacion dias', xlabel='Hora del dia', ylabel='Numero de ordenes',)
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Comparando la cantidad de pedidos al dia, comparando con miercoles y sabado muestra que el comportamiento es similar con algunas diferencias, muestra que el dia miercoles hay mas pedidos en la mañana, teniendo su mayor actividad entre las 10 am y las 5 pm; los sabados, comparando con el miercoles, hay mas pedidos en el transcurro de la tarde, muestra su mayor actividad igualmente de las 10am a las 17 pm, siendo el sabado el dia que hay mas pedidos, comparando con el miercoles

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
customer_order_counts = orders_df.groupby('user_id')['order_number'].max()
order_count_distribution = customer_order_counts.value_counts().sort_index()

# %%
order_count_distribution.plot(title='Distribución pedidos por Cliente', xlabel='Numero total pedidos',
                              ylabel='Numero de clientes')
plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# La grafica muesta una gran clientes que hacen aproximadamente 5 pedidos, despues de esto la grafica decrece bastante rapido, lo que indica que la empresa no tiene buena retencion de clientes, probablemente los clientes tienen alguna especie de descuento cuento cuendo hacen aproximadamente su quinto pedido

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
product_counts = order_products_df['product_id'].value_counts()

# %%
top_20_productos_id = product_counts.head(20)
top_20_df = top_20_productos_id.reset_index()
top_20_df.columns = ['product_id', 'order_count']

# %%
top_20_products_named = pd.merge(top_20_df, products_df, on='product_id', how='left')
top_20_products_final = top_20_products_named[['product_id', 'product_name', 'order_count']]
print(top_20_products_final)
# Out:
#     product_id              product_name  order_count
# 0        24852                    BANANA        66050
# 1        13176    BAG OF ORGANIC BANANAS        53297
# 2        21137      ORGANIC STRAWBERRIES        37039
# 3        21903      ORGANIC BABY SPINACH        33971
# 4        47209      ORGANIC HASS AVOCADO        29773
# 5        47766           ORGANIC AVOCADO        24689
# 6        47626               LARGE LEMON        21495
# 7        16797              STRAWBERRIES        20018
# 8        26209                     LIMES        19690
# 9        27845        ORGANIC WHOLE MILK        19600
# 10       27966       ORGANIC RASPBERRIES        19197
# 11       22935      ORGANIC YELLOW ONION        15898
# 12       24964            ORGANIC GARLIC        15292
# 13       45007          ORGANIC ZUCCHINI        14584
# 14       39275       ORGANIC BLUEBERRIES        13879
# 15       49683            CUCUMBER KIRBY        13675
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Se pudo en contrar el momemnto del dia en el que hay mas pedidos de igual forma el comportamiento de los pedidos durante el dia, siendo entre semana la mayor cantidad de peidos en la mañana y por la tarde los fines de semana.
#
# se pudo encontrar que la empresa tiene muy poca retencion de clientes, unicamente hay una gran cantidad de clientes que llegan a hacer hasta el 4 pedido, posteriormente pierden clientes de forma considerable
#
# de igual forma se pudo saber que el producto mas popular son los platanos y algunos similares productos organicos, lo que puede ayudar a incrementar este tipo de productos, posiblemente al ser productos organicos y tener un poca retencion del cliente, puede indicar que los porductos no son de buena calidad, lo que tendria sentido la poca cantidad de reordenes.

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
order_sizes = order_products_df.groupby('order_id').size()
print(order_sizes.describe())
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# dtype: float64

# %%
mode_size = order_sizes.mode()
print('tamaño mas frecuente de pedido', mode_size)
# Out:
# tamaño mas frecuente de pedido 0    5
# dtype: int64

# %%
plt.hist(order_sizes, bins=70)
mean_val = order_sizes.mean()
median_val = order_sizes.median()

plt.show()

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Primeramente se muestra que la cantidad de articulos pedidos mas frecuente son 5 articulos, ademas de que en la grafica muestra que la mayoria de los pedidos son paqueños enre 4 y 6 articulos por pedido, de igual forma indica que las personas comunmente piden entre 1 y cerca de 20 articulos por pedido, posterioremente dismuye drasticamente, indicando que es poco frecuente que hagan pedidos de 40 articulos. la media es un mejor indicardor debido a que hay una gran un gran numero de cantidad pedido, lo que el promedio no nos ayudaria mucho debido a la gran diferencia de personas que piden pocos articulo y las que piden mas de 20

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
reordered_products_df = order_products_df[order_products_df['reordered'] == 1]
reorder_counts = reordered_products_df['product_id'].value_counts()

# %%
top_20_reordered_ids = reorder_counts.head(20)
top_20_reordered_df = top_20_reordered_ids.reset_index()
top_20_reordered_df.columns = ['product_id', 'reorder_count']

# %%
top_20_reordered_named = pd.merge(top_20_reordered_df, products_df, on='product_id', how='left')
top_20_reordered_final = top_20_reordered_named[['product_id', 'product_name', 'reorder_count']]

# %%
print(top_20_reordered_final)
# Out:
#     product_id              product_name  reorder_count
# 0        24852                    BANANA          55763
# 1        13176    BAG OF ORGANIC BANANAS          44450
# 2        21137      ORGANIC STRAWBERRIES          28639
# 3        21903      ORGANIC BABY SPINACH          26233
# 4        47209      ORGANIC HASS AVOCADO          23629
# 5        47766           ORGANIC AVOCADO          18743
# 6        27845        ORGANIC WHOLE MILK          16251
# 7        47626               LARGE LEMON          15044
# 8        27966       ORGANIC RASPBERRIES          14748
# 9        16797              STRAWBERRIES          13945
# 10       26209                     LIMES          13327
# 11       22935      ORGANIC YELLOW ONION          11145
# 12       24964            ORGANIC GARLIC          10411
# 13       45007          ORGANIC ZUCCHINI          10076
# 14       49683            CUCUMBER KIRBY           9538
# 15       28204        ORGANIC FUJI APPLE           8989
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Estos resultados muestran que los proncipales productos son los organicos o los que son frescos, estos son los que mayoria de la gente prefiere, de igual forma hay productos lacteos lo que indican que las personas hacen estas comprar para su despensa

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
product_stats = order_products_df.groupby('product_id').agg(total_orders=('reordered', 'size'),
    total_reorders=('reordered', 'sum'))

# %%
product_stats['reorder_rate'] = product_stats['total_reorders'] / product_stats['total_orders']
product_stats = pd.merge(product_stats, products_df, on='product_id', how='left')
product_stats_sorted = product_stats.sort_values(by='reorder_rate', ascending=False)

# %%
print(product_stats_sorted[['product_name', 'reorder_rate', 'total_orders', 'total_reorders']])
# Out:
#                                         product_name  reorder_rate  \
# 28108                           ORGANIC FRENCH ROAST           1.0
# 7340                      BISSLI SMOKEY WHEAT SNACKS           1.0
# 28114                MUSHROOM LOVER'S VEGGIE BURGERS           1.0
# 41002                    FROZEN ORGANIC BLACKBERRIES           1.0
# 40998                                 REAL ZERO COLA           1.0
# ...                                              ...           ...
# 17561     CHEDDAR CHEESE WITH JALAPEÑO PEPPERS BLOCK           0.0
# 17543                    PLUM SMART 100% JUICE BLEND           0.0
# 28100  RISERVA PORCINI MUSHROOMS & WHITE TRUFFLE OIL           0.0
# 44                 SA EXTRA HOLD MOUSSE HAIR STYLING           0.0
# 22013                                        Unknown           0.0
#
#        total_orders  total_reorders
# 28108             2               2
# 7340              1               1
# 28114             2               2
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# Estos datos son solo estadisticos porque solo indica que productos se han comprado al menos por segunda vez, pero si nos puede mostrar son los pedidos que el cliente no vuelve a repetir estos productos pueden ser para un evento especial.

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
user_orders_products = pd.merge(orders_df, order_products_df, on='order_id')
user_reorder_stats = user_orders_products.groupby('user_id').agg(total_products=('reordered', 'size'),
    total_reorders=('reordered', 'sum'))

# %%
user_reorder_stats['user_reorder_rate'] = user_reorder_stats['total_reorders'] / user_reorder_stats['total_products']
user_reorder_stats['user_reorder_rate'].fillna(0, inplace=True)
print(user_reorder_stats.sort_values(by='user_reorder_rate', ascending=False))
print(user_reorder_stats.sort_values(by='user_reorder_rate', ascending=True))
# Out:
#          total_products  total_reorders  user_reorder_rate
# user_id
# 206164                1               1                1.0
# 17973                 2               2                1.0
# 196795                6               6                1.0
# 196792                9               9                1.0
# 196791               17              17                1.0
# ...                 ...             ...                ...
# 206136                6               0                0.0
# 136073               19               0                0.0
# 30                    3               0                0.0
# 66                    1               0                0.0
# 50200                 1               0                0.0
#
# [149626 rows x 3 columns]
#          total_products  total_reorders  user_reorder_rate
# user_id
# 167261               33               0                0.0
# 167258                6               0                0.0
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# La tabla muestra a primera estancia que los primeros clientes que aparecen en la tabla son mas leales, sus pedidos son pequeños por lo que puede ser un indicador que solo estan reponiendo su lista de compras. pero hay una gran cantidad de clientes que no vulven a hacer un pedido

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Excelente trabajo. Los resultados son los esperados.
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Nota que sería muy interesante crear un histograma de la tasa de repetición.
#
# </div>
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
first_in_cart_df = order_products_df[order_products_df['add_to_cart_order'] == 1]
first_in_cart_counts = first_in_cart_df['product_id'].value_counts()

# %%
top_20_first_ids = first_in_cart_counts.head(20)
top_20_first_df = top_20_first_ids.reset_index()
top_20_first_df.columns = ['product_id', 'first_add_count']

# %%
top_20_first_named = pd.merge(top_20_first_df, products_df, on='product_id', how='left')
top_20_first_final = top_20_first_named[['product_id', 'product_name', 'first_add_count']]
print(top_20_first_final)
# Out:
#     product_id                 product_name  first_add_count
# 0        24852                       BANANA            15562
# 1        13176       BAG OF ORGANIC BANANAS            11026
# 2        27845           ORGANIC WHOLE MILK             4363
# 3        21137         ORGANIC STRAWBERRIES             3946
# 4        47209         ORGANIC HASS AVOCADO             3390
# 5        21903         ORGANIC BABY SPINACH             3336
# 6        47766              ORGANIC AVOCADO             3044
# 7        19660                 SPRING WATER             2336
# 8        16797                 STRAWBERRIES             2308
# 9        27966          ORGANIC RASPBERRIES             2024
# 10       44632   SPARKLING WATER GRAPEFRUIT             1914
# 11       49235          ORGANIC HALF & HALF             1797
# 12       47626                  LARGE LEMON             1737
# 13         196                         SODA             1733
# ...

# %% [markdown]
# Escribe aquí tus conclusiones
#
# La tabla muesta que el primer producto en el que piensan las personas son en bananas, son el producto que primeramente la gente busca para hacer sus compras, la tabla muestra productos de primera necesidad. de igual forma, aparece por primera vez productos de bebida, esto casi coicide con los productos mas populares y reordenados

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# Los productos se listan correctamente y los conteos son los esperados.
#
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# En este proyedcto primeramente se analizaron los tipos de datos para poder encontrar errores en la base de datos y poder correguirlos de forma coherente para que se pueda hacer un analisis eficiente en la base de datos.
#
# Se analizaron y corrguieron tanto los valores duplicados como los ausentes, el problema mas grave que se encontro con la limitante de que no se registran la adicion de productos cuando son mas de 64 articulos, se neceita solucionar para considerar a las personas que hacen productos mas grandes.
#
# Se realizaron graficas para analizar los patrones de las compras y de los clientes, se pudo encontrar que la mayoria de los pedidos se realizan al inicio y fin de semana de igual forma que las personas prefieren comprar parte del medio dia y por la tarde.
#
# Se pudo observar que las personas que son constantes unicamente hacen pedidos para reponer sus despensas y hay pocos usuarios que hacen pedidos grandes, estos son menos frecuentes. esto por los productos de primera necesidad que adquieren
#
# El problema principal que se detecto es que tienen muy poca retencion de clientes, hay mucho pocos clientes que hacen una recompra, se tienen que trabajar en mejores estrateguias para poder retener una mayor cantidad de clientes
#
# Se pudo encontrar que las babanas son los mas pedidos y frecuentes en la plataforma donde tambien los productos organicos son pedidos frecuentes, de la misma forma se pudo notar que las bananas y los productos organicos son los productos que primero piensan las personas al momento de comenzar sus compras
#
# La recomendacion no conciste en ampliar sus productos, si no en trabajar en retener los clientes, posicionarse mejor como en la mejor opcion para abastecer los productos de primera necesidad, asegurar la calidad y disponibilidad de las bananas y productos organicos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del Revisor #1</b> <a class="tocSkip"></a>
#
# La conclusión refleja bien el proceso seguido (limpieza, detección de problemas y análisis de patrones) y destaca hallazgos clave como la importancia de los productos básicos/ orgánicos y la baja retención de clientes.
#
# </div>
